# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('country_vaccinations.csv')

# %%
df.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     31458
# people_vaccinated                      32943
# people_fully_vaccinated                35556
# daily_vaccinations_raw                 37925
# daily_vaccinations                       366
# total_vaccinations_per_hundred         31458
# people_vaccinated_per_hundred          32943
# people_fully_vaccinated_per_hundred    35556
# daily_vaccinations_per_million           366
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df[['country','iso_code','date','vaccines','source_name']]
# Out:
#            country iso_code        date  \
# 0      Afghanistan      AFG  2021-02-22
# 1      Afghanistan      AFG  2021-02-23
# 2      Afghanistan      AFG  2021-02-24
# 3      Afghanistan      AFG  2021-02-25
# 4      Afghanistan      AFG  2021-02-26
# ...            ...      ...         ...
# 66325     Zimbabwe      ZWE  2021-12-22
# 66326     Zimbabwe      ZWE  2021-12-23
# 66327     Zimbabwe      ZWE  2021-12-24
# 66328     Zimbabwe      ZWE  2021-12-25
# 66329     Zimbabwe      ZWE  2021-12-26
#
#                                                 vaccines  \
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...                                                  ...
# 66325  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# ...

# %% [markdown]
# data=df

# %%
data.shape
# Out:
# (66330, 15)

# %%
data.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %%
data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.487200e+04       3.338700e+04             3.077400e+04
# mean         3.357830e+07       1.342228e+07             9.778293e+06
# std          1.730459e+08       5.276935e+07             3.831746e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          3.925522e+05       2.778055e+05             1.656195e+05
# 50%          2.563082e+06       1.639806e+06             1.140760e+06
# 75%          1.207973e+07       6.512414e+06             5.444750e+06
# max          2.769530e+09       1.225000e+09             1.193466e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            2.840500e+04        6.596400e+04
# mean             2.772051e+05        1.364650e+05
# std              1.273848e+06        8.208942e+05
# min              0.000000e+00        0.000000e+00
# 25%              5.371000e+03        1.005000e+03
# ...

# %%
data['vaccines'].value_counts()#COUNTING VACCINES
# Out:
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech     8152
# Oxford/AstraZeneca                                                4992
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                      4940
# Oxford/AstraZeneca, Pfizer/BioNTech                               3628
# Moderna, Pfizer/BioNTech                                          2611
#                                                                   ...
# Covaxin, Oxford/AstraZeneca                                        218
# Johnson&Johnson, Oxford/AstraZeneca, Sinovac                       208
# EpiVacCorona, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V     183
# Johnson&Johnson, Moderna                                           155
# Johnson&Johnson, Pfizer/BioNTech, Sinopharm/Beijing                121
# Name: vaccines, Length: 77, dtype: int64

# %%
#FINDING THE NULL values
data.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     31458
# people_vaccinated                      32943
# people_fully_vaccinated                35556
# daily_vaccinations_raw                 37925
# daily_vaccinations                       366
# total_vaccinations_per_hundred         31458
# people_vaccinated_per_hundred          32943
# people_fully_vaccinated_per_hundred    35556
# daily_vaccinations_per_million           366
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.sort_values(by=['people_fully_vaccinated_per_hundred'])
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 59455     Timor      TLS  2021-06-08             93169.0            93152.0
# 10296    Canada      CAN  2020-12-30             85497.0            85495.0
# 10295    Canada      CAN  2020-12-29             72057.0            72055.0
# 10294    Canada      CAN  2020-12-28             59041.0            59040.0
# 10293    Canada      CAN  2020-12-27             52419.0            52418.0
# ...         ...      ...         ...                 ...                ...
# 66207  Zimbabwe      ZWE  2021-08-26                 NaN                NaN
# 66218  Zimbabwe      ZWE  2021-09-06                 NaN                NaN
# 66224  Zimbabwe      ZWE  2021-09-12                 NaN                NaN
# 66229  Zimbabwe      ZWE  2021-09-17                 NaN                NaN
# 66290  Zimbabwe      ZWE  2021-11-17                 NaN                NaN
#
# ...

# %%
dwh_data=df[['country','people_vaccinated','people_fully_vaccinated','vaccines']]

# %%
dwh_data
# Out:
#            country  people_vaccinated  people_fully_vaccinated  \
# 0      Afghanistan                0.0                      NaN
# 1      Afghanistan                NaN                      NaN
# 2      Afghanistan                NaN                      NaN
# 3      Afghanistan                NaN                      NaN
# 4      Afghanistan                NaN                      NaN
# ...            ...                ...                      ...
# 66325     Zimbabwe          4078945.0                3088665.0
# 66326     Zimbabwe          4089315.0                3098813.0
# 66327     Zimbabwe          4095685.0                3105091.0
# 66328     Zimbabwe          4100069.0                3108980.0
# 66329     Zimbabwe          4103288.0                3111352.0
#
#                                                 vaccines
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...

# %%
clean_data=data.dropna()

# %%
sns.heatmap(clean_data.isnull())
# Out:
# <AxesSubplot:>

# %%
clean_data[["country","date","total_vaccinations"]]
# Out:
#            country        date  total_vaccinations
# 94     Afghanistan  2021-05-27            593313.0
# 101    Afghanistan  2021-06-03            630305.0
# 318        Albania  2021-02-18              3049.0
# 400        Albania  2021-05-11            622507.0
# 401        Albania  2021-05-12            632676.0
# ...            ...         ...                 ...
# 66325     Zimbabwe  2021-12-22           7167610.0
# 66326     Zimbabwe  2021-12-23           7188128.0
# 66327     Zimbabwe  2021-12-24           7200776.0
# 66328     Zimbabwe  2021-12-25           7209049.0
# 66329     Zimbabwe  2021-12-26           7214640.0
#
# [24759 rows x 3 columns]

# %%
sns.catplot(x='country',y='people_fully_vaccinated',data=data,jitter=False,height=4,aspect=1.5)

# %%
clean_data[["vaccines","date","total_vaccinations"]]
# Out:
#                                                 vaccines        date  \
# 94     Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  2021-05-27
# 101    Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...  2021-06-03
# 318    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...  2021-02-18
# 400    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...  2021-05-11
# 401    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...  2021-05-12
# ...                                                  ...         ...
# 66325  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  2021-12-22
# 66326  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  2021-12-23
# 66327  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  2021-12-24
# 66328  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  2021-12-25
# 66329  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  2021-12-26
#
#        total_vaccinations
# 94               593313.0
# 101              630305.0
# 318                3049.0
# 400              622507.0
# ...

# %%
plt.xlabel("Country",color='Red')
plt.ylabel("PEOPLE VACCINATED",color='red')
x=data["country"]
y=data["people_fully_vaccinated"]
plt.title("Covid Vaccination Progress",color="red")
plt.plot(x,y)
plt.grid()
plt.show()

# %%
Canada_records=data.loc[data['country']=='Canada']
print(Canada_records)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 10280  Canada      CAN  2020-12-14                 5.0                5.0
# 10281  Canada      CAN  2020-12-15               727.0              727.0
# 10282  Canada      CAN  2020-12-16              3025.0             3025.0
# 10283  Canada      CAN  2020-12-17              7279.0             7279.0
# 10284  Canada      CAN  2020-12-18             11296.0            11296.0
# ...       ...      ...         ...                 ...                ...
# 10652  Canada      CAN  2021-12-21          65820170.0         31543937.0
# 10653  Canada      CAN  2021-12-22          66253753.0         31579905.0
# 10654  Canada      CAN  2021-12-23          66725442.0         31615049.0
# 10655  Canada      CAN  2021-12-24          66963629.0         31638500.0
# 10656  Canada      CAN  2021-12-25          66963629.0         31638500.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
plt.xlabel("Fully Vaccinated People",color='black')
plt.ylabel("Total Vaccinations",color='black')
x=Canada_records["people_fully_vaccinated"]
y=Canada_records["total_vaccinations"]
plt.title("Covid Vaccination Progress of Canada",color="red")
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import mysql.connector as msql
from mysql.connector import Error

# %%
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='m2@NfTm2')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE Covid_DWH")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Database is created

# %%
dwh_data.dtypes
# Out:
# country                     object
# people_vaccinated          float64
# people_fully_vaccinated    float64
# vaccines                    object
# dtype: object

# %%
dwh_data=dwh_data.fillna(0)

# %%
dwh_data
# Out:
#            country  people_vaccinated  people_fully_vaccinated  \
# 0      Afghanistan                0.0                      0.0
# 1      Afghanistan                0.0                      0.0
# 2      Afghanistan                0.0                      0.0
# 3      Afghanistan                0.0                      0.0
# 4      Afghanistan                0.0                      0.0
# ...            ...                ...                      ...
# 66325     Zimbabwe          4078945.0                3088665.0
# 66326     Zimbabwe          4089315.0                3098813.0
# 66327     Zimbabwe          4095685.0                3105091.0
# 66328     Zimbabwe          4100069.0                3108980.0
# 66329     Zimbabwe          4103288.0                3111352.0
#
#                                                 vaccines
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# ...

# %%
try:
    conn = msql.connect(host='localhost', 
                           database='Covid_DWH', user='root', 
                           password='m2@NfTm2')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS Covid_DWH')
        print('Creating table....')
        cursor.execute('CREATE TABLE Country_vac(country varchar(200), people_vaccinated FLOAT,people_fully_vaccinated FLOAT,vaccines varchar(500))')
        conn.commit()
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('covid_dwh',)
# Creating table....

# %%
try:
     for i,row in dwh_data.iterrows():
            sql = "INSERT INTO Covid_DWH.Country_vac VALUES (%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted") 
            conn.commit()
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...
